# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

from bs4 import BeautifulSoup
import requests

print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.18.1-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  26.71 MB/s
# geopy-1.18.1-p 100% |################################| Time: 0:00:00  36.92 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  50.23 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  38.30 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  41.62 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  46.77 MB/s
# Libraries imported.

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_R'
url = requests.get(url).text
soup = BeautifulSoup(url, 'lxml')

# %%
can_zipinfo = soup.find('table') #will get the table by finding the table tag
col_values = can_zipinfo.find_all('td') #get the values from the td sub elements under the table tag.
postCode = can_zipinfo.find_all('b')
neighborhood = can_zipinfo.find_all('a')
print(neighborhood[0].text)
#print(sub_col_vals)

postCode_cnt = len(postCode)
neigh_cnt = len(neighborhood)

postcode = []
#borough = []
Neighborhood = []

for i in range(0, postCode_cnt, 3):
    postcode.append(postCode[i].text)
for i in range(0, neigh_cnt, 3):
    Neighborhood.append(neighborhood[i].text)

    df_can_postcode = pd.DataFrame(data=[postcode, Neighborhood]).transpose()
df_can_postcode.columns = ['Postcode', 'Neighborhood']
df_can_postcode.head()
# Out:
# Selkirk
#   Postcode       Neighborhood
# 0      R1A            Selkirk
# 1      R4A      West St. Paul
# 2      R7A          Flin Flon
# 3      R1B           Winnipeg
# 4      R4B  Exchange District

# %%
winni_map = folium.Map(location=[49.8951, -97.1384], zoom_start=10)
# display world map
winni_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'SHRITVCGO0MC0HEHQCULOXULH3ZLVN032GWO3DW2P2IPA5GV' # your Foursquare ID
CLIENT_SECRET = 'ZLYWFORC4LFYID2ACKEGGZ44TTUOE3LNJA5KENUL5B5IQDVM' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: SHRITVCGO0MC0HEHQCULOXULH3ZLVN032GWO3DW2P2IPA5GV
# CLIENT_SECRET:ZLYWFORC4LFYID2ACKEGGZ44TTUOE3LNJA5KENUL5B5IQDVM

# %%
#Since I am moving for study to Red River College, I want to explore area around that.
address = '2055 Notre Dame Ave, Winnipeg, Canada'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:4: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# 49.9053481 -97.1713554

# %%
#Find cheap food around
search_query = 'food'
radius = 5000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# Out:
# food .... OK!
# {'meta': {'code': 200, 'requestId': '5c4751831ed2193f114475f3'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'primary': True,
#       'shortName': 'Food Court'}],
#     'hasPerk': False,
#     'id': '4b71bec6f964a520e5592de3',
#     'location': {'address': '393 Portage Ave.',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'crossStreet': 'in Portage Place Shopping Centre',
#      'distance': 2263,
#      'formattedAddress': ['393 Portage Ave. (in Portage Place Shopping Centre)',
#       'Winnipeg MB R3B 3H6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.89250497749786,
#        'lng': -97.1468790698822}],
#      'lat': 49.89250497749786,
#      'lng': -97.1468790698822,
#      'postalCode': 'R3B 3H6',
#      'state': 'MB'},
#     'name': 'Food Court - Portage Place Shopping Centre',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'primary': True,
#       'shortName': 'Food Court'}],
#     'hasPerk': False,
#     'id': '50ae68e0498ec34db35684eb',
#     'location': {'address': '333 St. Mary Avenue',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'crossStreet': 'Hargrave Street',
#      'distance': 2598,
#      'formattedAddress': ['333 St. Mary Avenue (Hargrave Street)',
#       'Winnipeg MB R3C 4A5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.89084709171012,
#        'lng': -97.14296656374589}],
#      'lat': 49.89084709171012,
#      'lng': -97.14296656374589,
#      'postalCode': 'R3C 4A5',
#      'state': 'MB'},
#     'name': 'cityplace Food Court',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f9941735',
#       'name': 'Food & Drink Shop',
#       'pluralName': 'Food & Drink Shops',
#       'primary': True,
#       'shortName': 'Food & Drink'}],
#     'hasPerk': False,
#     'id': '4c956e9f94a0236a8d7e9612',
#     'location': {'address': '1094 Notre Dame Ave.',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'crossStreet': 'Garfield',
#      'distance': 313,
#      'formattedAddress': ['1094 Notre Dame Ave. (Garfield)',
#       'Winnipeg MB R3E 0N7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.90667,
#        'lng': -97.17522}],
#      'lat': 49.90667,
#      'lng': -97.17522,
#      'postalCode': 'R3E 0N7',
#      'state': 'MB'},
#     'name': 'K&B Lucky Lotto Food Store',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'primary': True,
#       'shortName': 'Food Court'}],
#     'hasPerk': False,
#     'id': '4ce0300170bba1cd30e46ac4',
#     'location': {'address': '1485 Portage Ave.',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 3217,
#      'formattedAddress': ['1485 Portage Ave.',
#       'Winnipeg MB R3G 0W4',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.88246633553492,
#        'lng': -97.19876752875557}],
#      'lat': 49.88246633553492,
#      'lng': -97.19876752875557,
#      'postalCode': 'R3G 0W4',
#      'state': 'MB'},
#     'name': 'Polo Park Food Court',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4c95754d58d4b60cf1e03229',
#     'location': {'address': '708 McPhillips St',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'crossStreet': 'Manitoba Ave',
#      'distance': 2215,
#      'formattedAddress': ['708 McPhillips St (Manitoba Ave)',
#       'Winnipeg MB R2X 2H5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.92522129182919,
#        'lng': -97.16965415541489}],
#      'lat': 49.92522129182919,
#      'lng': -97.16965415541489,
#      'postalCode': 'R2X 2H5',
#      'state': 'MB'},
#     'name': 'Chinese Food Delivery',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'primary': True,
#       'shortName': 'Convenience Store'}],
#     'hasPerk': False,
#     'id': '4e67ef0714952e0a131b0a63',
#     'location': {'address': 'Sargent',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 941,
#      'formattedAddress': ['Sargent', 'Winnipeg MB', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.896972807229695,
#        'lng': -97.173186255302}],
#      'lat': 49.896972807229695,
#      'lng': -97.173186255302,
#      'state': 'MB'},
#     'name': 'Tindahan Food Mart',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'primary': True,
#       'shortName': 'Food Court'}],
#     'hasPerk': False,
#     'id': '57782366498e189815433ea3',
#     'location': {'address': '820 Sherbrook St.',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'crossStreet': 'Green Owl Zone, Level 2',
#      'distance': 1074,
#      'formattedAddress': ['820 Sherbrook St. (Green Owl Zone, Level 2)',
#       'Winnipeg MB R3A 1R9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.903475227947304,
#        'lng': -97.15666042251377}],
#      'lat': 49.903475227947304,
#      'lng': -97.15666042251377,
#      'postalCode': 'R3A 1R9',
#      'state': 'MB'},
#     'name': 'Health Sciences Center Food Court',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '5453de49498eade8af355881',
#       'name': 'Business Service',
#       'pluralName': 'Business Services',
#       'primary': True,
#       'shortName': 'Business Services'}],
#     'hasPerk': False,
#     'id': '579d9984498ec3cf1aecb8ed',
#     'location': {'address': '1412 Portage Ave',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 2928,
#      'formattedAddress': ['1412 Portage Ave', 'Winnipeg MB R3G 0V5', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.882154,
#        'lng': -97.190631}],
#      'lat': 49.882154,
#      'lng': -97.190631,
#      'postalCode': 'R3G 0V5',
#      'state': 'MB'},
#     'name': 'United Food & Commercial Workers Local 832',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'primary': True,
#       'shortName': 'Grocery Store'}],
#     'hasPerk': False,
#     'id': '4b86f2d6f964a52094a731e3',
#     'location': {'address': '905 Portage Ave',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 2205,
#      'formattedAddress': ['905 Portage Ave', 'Winnipeg MB', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.88555003781746,
#        'lng': -97.17028050519141}],
#      'lat': 49.88555003781746,
#      'lng': -97.17028050519141,
#      'state': 'MB'},
#     'name': 'FoodFare',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'primary': True,
#       'shortName': 'Fast Food'}],
#     'hasPerk': False,
#     'id': '51f011b6498e45977ef7599b',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 2730,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.893492268787455,
#        'lng': -97.13801850593904}],
#      'lat': 49.893492268787455,
#      'lng': -97.13801850593904},
#     'name': 'Food Court Winnipeg Square',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4fa9ba8ee4b0f00008b05e83',
#     'location': {'address': '1111 Logan Ave',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 992,
#      'formattedAddress': ['1111 Logan Ave', 'Winnipeg MB', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.914262991762236,
#        'lng': -97.17159267827398}],
#      'lat': 49.914262991762236,
#      'lng': -97.17159267827398,
#      'state': 'MB'},
#     'name': 'Canton Food Gallery',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'id': '56aa371be4b08b9a8d573550',
#       'name': 'Food Service',
#       'pluralName': 'Food Services',
#       'primary': True,
#       'shortName': 'Food Service'}],
#     'hasPerk': False,
#     'id': '5772b168498e9394610fc5e2',
#     'location': {'address': '840 Erin St',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 1899,
#      'formattedAddress': ['840 Erin St', 'Winnipeg MB R3G 2W5', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.890691,
#        'lng': -97.184928}],
#      'lat': 49.890691,
#      'lng': -97.184928,
#      'postalCode': 'R3G 2W5',
#      'state': 'MB'},
#     'name': 'Food For Thought',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'primary': True,
#       'shortName': 'Shop'}],
#     'hasPerk': False,
#     'id': '4fad63fba17c839745249f16',
#     'location': {'address': '561 Sargent Avenue',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 1421,
#      'formattedAddress': ['561 Sargent Avenue',
#       'Winnipeg MB R3B 1W4',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.89662485669814,
#        'lng': -97.15688467025757}],
#      'lat': 49.89662485669814,
#      'lng': -97.15688467025757,
#      'postalCode': 'R3B 1W4',
#      'state': 'MB'},
#     'name': "Will's Sargent Food Mart",
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '55a030e3498e98f115e10d30',
#     'location': {'address': '951 Erin St',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 1580,
#      'formattedAddress': ['951 Erin St', 'Winnipeg MB', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.893649,
#        'lng': -97.183838}],
#      'lat': 49.893649,
#      'lng': -97.183838,
#      'state': 'MB'},
#     'name': 'Russell Food Equipament',
#     'referralId': 'v-1548177795'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4c2a01d3fe6e2d7f9fa8553c',
#     'location': {'address': '941 erin',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 1614,
#      'formattedAddress': ['941 erin', 'Winnipeg MB', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.893444900689985,
#        'lng': -97.1842276084622}],
#      'lat': 49.893444900689985,
#      'lng': -97.1842276084622,
#      'state': 'MB'},
#     'name': 'Russell Food Equipment',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'primary': True,
#       'shortName': 'Grocery Store'}],
#     'hasPerk': False,
#     'id': '4bc88fd10050b7139c98ba3b',
#     'location': {'address': '365 Royal Ave.',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'crossStreet': 'at Powers St.',
#      'distance': 5123,
#      'formattedAddress': ['365 Royal Ave. (at Powers St.)',
#       'Winnipeg MB R2V 1J5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.94006,
#        'lng': -97.12442}],
#      'lat': 49.94006,
#      'lng': -97.12442,
#      'postalCode': 'R2V 1J5',
#      'state': 'MB'},
#     'name': 'Royal Food Store',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a36',
#       'name': 'Warehouse',
#       'pluralName': 'Warehouses',
#       'primary': True,
#       'shortName': 'Warehouse'}],
#     'hasPerk': False,
#     'id': '5c2f8f50e0c0c9002c801366',
#     'location': {'address': '1265 Empress St',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 1563,
#      'formattedAddress': ['1265 Empress St', 'Winnipeg MB R3E 3N9', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.904901,
#        'lng': -97.193154}],
#      'lat': 49.904901,
#      'lng': -97.193154,
#      'postalCode': 'R3E 3N9',
#      'state': 'MB'},
#     'name': 'Sobey’s Food  Warehouse',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'primary': True,
#       'shortName': 'Office'}],
#     'hasPerk': False,
#     'id': '4ecd3e719a528a8ec7ae9848',
#     'location': {'address': '4-640 Broadway',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'crossStreet': 'Langside Ave',
#      'distance': 2457,
#      'formattedAddress': ['4-640 Broadway (Langside Ave)',
#       'Winnipeg MB',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.885417749784885,
#        'lng': -97.15663284312373}],
#      'lat': 49.885417749784885,
#      'lng': -97.15663284312373,
#      'state': 'MB'},
#     'name': 'Food Matters Manitoba',
#     'referralId': 'v-1548177795'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4cce24c8a9259521c9126f29',
#     'location': {'address': '515 Portage',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'crossStreet': 'Spence',
#      'distance': 1926,
#      'formattedAddress': ['515 Portage (Spence)',
#       'Winnipeg MB r3b 2e9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.89205255126113,
#        'lng': -97.15416003721585}],
#      'lat': 49.89205255126113,
#      'lng': -97.15416003721585,
#      'postalCode': 'r3b 2e9',
#      'state': 'MB'},
#     'name': 'Diversity Food services',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'primary': True,
#       'shortName': 'Grocery Store'}],
#     'hasPerk': False,
#     'id': '4bb2bdea2397b713ab7737b3',
#     'location': {'address': '115 Maryland St.',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 2711,
#      'formattedAddress': ['115 Maryland St.', 'Winnipeg MB', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.88197122112876,
#        'lng': -97.16075039351034}],
#      'lat': 49.88197122112876,
#      'lng': -97.16075039351034,
#      'state': 'MB'},
#     'name': 'FoodFare',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'id': '56aa371be4b08b9a8d573550',
#       'name': 'Food Service',
#       'pluralName': 'Food Services',
#       'primary': True,
#       'shortName': 'Food Service'}],
#     'hasPerk': False,
#     'id': '4c75bc03604a370477af8349',
#     'location': {'address': '101 Hutchings St',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 3700,
#      'formattedAddress': ['101 Hutchings St', 'Winnipeg MB R2X 2V4', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.937699,
#        'lng': -97.183256}],
#      'lat': 49.937699,
#      'lng': -97.183256,
#      'postalCode': 'R2X 2V4',
#      'state': 'MB'},
#     'name': 'Pratts Wholesale/Food Service',
#     'referralId': 'v-1548177795'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4c7bcf0a3badb1f76be75554',
#     'location': {'address': '202-1555 St.James st',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 2067,
#      'formattedAddress': ['202-1555 St.James st', 'Winnipeg MB', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.910766,
#        'lng': -97.198935}],
#      'lat': 49.910766,
#      'lng': -97.198935,
#      'state': 'MB'},
#     'name': 'Champs Food Systems Ltd.',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'primary': True,
#       'shortName': 'Sandwiches'}],
#     'hasPerk': False,
#     'id': '53f4d468498eacab76906dc2',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 3055,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.88997268676758,
#        'lng': -97.13605499267578}],
#      'lat': 49.88997268676758,
#      'lng': -97.13605499267578},
#     'name': 'Food For Thought',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f9941735',
#       'name': 'Food & Drink Shop',
#       'pluralName': 'Food & Drink Shops',
#       'primary': True,
#       'shortName': 'Food & Drink'}],
#     'hasPerk': False,
#     'id': '502a9f00e4b00255ffde5a85',
#     'location': {'address': '116 Park Road West',
#      'cc': 'CA',
#      'city': 'Steinbach',
#      'country': 'Canada',
#      'distance': 2046,
#      'formattedAddress': ['116 Park Road West', 'Steinbach MB', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.891614,
#        'lng': -97.152381}],
#      'lat': 49.891614,
#      'lng': -97.152381,
#      'state': 'MB'},
#     'name': 'Health Food',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'primary': True,
#       'shortName': 'Convenience Store'}],
#     'hasPerk': False,
#     'id': '51410aa0e4b0fc7cdff4566a',
#     'location': {'address': '521 St. Mary Ave',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 2256,
#      'formattedAddress': ['521 St. Mary Ave', 'Winnipeg MB', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.88925697612206,
#        'lng': -97.1522068977356}],
#      'lat': 49.88925697612206,
#      'lng': -97.1522068977356,
#      'state': 'MB'},
#     'name': 'Hi Rise Food Mart',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'primary': True,
#       'shortName': 'Vietnamese'}],
#     'hasPerk': False,
#     'id': '4d0f98bbb765224be6a5e532',
#     'location': {'address': '360 Main St. in Winnipeg Square',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 2710,
#      'formattedAddress': ['360 Main St. in Winnipeg Square',
#       'Winnipeg MB R3C 1A9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.893594376510244,
#        'lng': -97.13824997358253}],
#      'lat': 49.893594376510244,
#      'lng': -97.13824997358253,
#      'postalCode': 'R3C 1A9',
#      'state': 'MB'},
#     'name': 'Vinh Long Vietnamese Fast Food',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'primary': True,
#       'shortName': 'Grocery Store'}],
#     'hasPerk': False,
#     'id': '4b61f185f964a5208e2c2ae3',
#     'location': {'address': '247 Lilac St',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'crossStreet': 'at Corydon Ave',
#      'distance': 4093,
#      'formattedAddress': ['247 Lilac St (at Corydon Ave)',
#       'Winnipeg MB R3M 2S2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.869766471765004,
#        'lng': -97.15696148934019}],
#      'lat': 49.869766471765004,
#      'lng': -97.15696148934019,
#      'postalCode': 'R3M 2S2',
#      'state': 'MB'},
#     'name': 'FoodFare',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f6941735',
#       'name': 'Department Store',
#       'pluralName': 'Department Stores',
#       'primary': True,
#       'shortName': 'Department Store'}],
#     'hasPerk': False,
#     'id': '4b96cda3f964a520a5e534e3',
#     'location': {'address': '2285 Portage Ave',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'crossStreet': 'at Mount Royal Rd',
#      'distance': 6187,
#      'formattedAddress': ['2285 Portage Ave (at Mount Royal Rd)',
#       'Winnipeg MB R3J 0L9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.876531920344135,
#        'lng': -97.24512594775156}],
#      'lat': 49.876531920344135,
#      'lng': -97.24512594775156,
#      'postalCode': 'R3J 0L9',
#      'state': 'MB'},
#     'name': 'FoodFare',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'primary': True,
#       'shortName': 'Government'}],
#     'hasPerk': False,
#     'id': '5138e799e4b0e1960888e04f',
#     'location': {'address': '167 Lombard Avenue',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'distance': 2650,
#      'formattedAddress': ['167 Lombard Avenue', 'Winnipeg MB', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.89572706946155,
#        'lng': -97.13753926719653}],
#      'lat': 49.89572706946155,
#      'lng': -97.13753926719653,
#      'state': 'MB'},
#     'name': 'Agriculture & Agri-Food Canada',
#     'referralId': 'v-1548177795'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'primary': True,
#       'shortName': 'Sandwiches'}],
#     'hasPerk': False,
#     'id': '574748e2498ef9ed5bacf511',
#     'location': {'address': '360 Main Street',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'country': 'Canada',
#      'crossStreet': 'William Stephenson Way',
#      'distance': 2732,
#      'formattedAddress': ['360 Main Street (William Stephenson Way)',
#       'Winnipeg MB R3Z 3Z8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.89352854861032,
#        'lng': -97.13794827461243}],
#      'lat': 49.89352854861032,
#      'lng': -97.13794827461243,
#      'postalCode': 'R3Z 3Z8',
#      'state': 'MB'},
#     'name': 'Meltwich Food Co.',
#     'referralId': 'v-1548177795'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered

dataframe_filtered.name
# Out:
# 0     Food Court - Portage Place Shopping Centre
# 1                           cityplace Food Court
# 2                     K&B Lucky Lotto Food Store
# 3                           Polo Park Food Court
# 4                          Chinese Food Delivery
# 5                             Tindahan Food Mart
# 6              Health Sciences Center Food Court
# 7     United Food & Commercial Workers Local 832
# 8                                       FoodFare
# 9                     Food Court Winnipeg Square
# 10                           Canton Food Gallery
# 11                              Food For Thought
# 12                      Will's Sargent Food Mart
# 13                       Russell Food Equipament
# 14                        Russell Food Equipment
# 15                              Royal Food Store
# 16                       Sobey’s Food  Warehouse
# 17                         Food Matters Manitoba
# 18                       Diversity Food services
# 19                                      FoodFare
# 20                 Pratts Wholesale/Food Service
# 21                      Champs Food Systems Ltd.
# 22                              Food For Thought
# 23                                   Health Food
# 24                             Hi Rise Food Mart
# 25                Vinh Long Vietnamese Fast Food
# 26                                      FoodFare
# 27                                      FoodFare
# 28                Agriculture & Agri-Food Canada
# 29                             Meltwich Food Co.
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Red RIver COllege',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# %%
#add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=2000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)
	
	
	
	
	
result_venues = getNearbyVenues(names=dataframe_filtered['name'],
                                   latitudes=dataframe_filtered['lat'],
                                   longitudes=dataframe_filtered['lng']
                                  )
result_venues.groupby('Neighborhood').count()
# Out:
# Food Court - Portage Place Shopping Centre
# cityplace Food Court
# K&B Lucky Lotto Food Store
# Polo Park Food Court
# Chinese Food Delivery
# Tindahan Food Mart
# Health Sciences Center Food Court
# United Food & Commercial Workers Local 832
# FoodFare
# Food Court Winnipeg Square
# Canton Food Gallery
# Food For Thought
# Will's Sargent Food Mart
# Russell Food Equipament
# Russell Food Equipment
# Royal Food Store
# Sobey’s Food  Warehouse
# Food Matters Manitoba
# Diversity Food services
# FoodFare
# Pratts Wholesale/Food Service
# Champs Food Systems Ltd.
# Food For Thought
# Health Food
# Hi Rise Food Mart
# Vinh Long Vietnamese Fast Food
# FoodFare
# FoodFare
# Agriculture & Agri-Food Canada
# Meltwich Food Co.
#                                             Neighborhood Latitude  \
# Neighborhood
# Agriculture & Agri-Food Canada                                 30
# Canton Food Gallery                                            30
# Champs Food Systems Ltd.                                       30
# Chinese Food Delivery                                          30
# Diversity Food services                                        30
# Food Court - Portage Place Shopping Centre                     30
# Food Court Winnipeg Square                                     30
# Food For Thought                                               60
# Food Matters Manitoba                                          30
# FoodFare                                                      120
# Health Food                                                    30
# Health Sciences Center Food Court                              30
# Hi Rise Food Mart                                              30
# K&B Lucky Lotto Food Store                                     30
# Meltwich Food Co.                                              30
# Polo Park Food Court                                           30
# Pratts Wholesale/Food Service                                  30
# Royal Food Store                                               30
# Russell Food Equipament                                        30
# Russell Food Equipment                                         30
# Sobey’s Food  Warehouse                                        30
# Tindahan Food Mart                                             30
# United Food & Commercial Workers Local 832                     30
# Vinh Long Vietnamese Fast Food                                 30
# Will's Sargent Food Mart                                       30
# cityplace Food Court                                           30
#
#                                             Neighborhood Longitude  Venue  \
# Neighborhood
# Agriculture & Agri-Food Canada                                  30     30
# Canton Food Gallery                                             30     30
# Champs Food Systems Ltd.                                        30     30
# Chinese Food Delivery                                           30     30
# Diversity Food services                                         30     30
# Food Court - Portage Place Shopping Centre                      30     30
# Food Court Winnipeg Square                                      30     30
# Food For Thought                                                60     60
# Food Matters Manitoba                                           30     30
# FoodFare                                                       120    120
# Health Food                                                     30     30
# Health Sciences Center Food Court                               30     30
# Hi Rise Food Mart                                               30     30
# K&B Lucky Lotto Food Store                                      30     30
# Meltwich Food Co.                                               30     30
# Polo Park Food Court                                            30     30
# Pratts Wholesale/Food Service                                   30     30
# Royal Food Store                                                30     30
# Russell Food Equipament                                         30     30
# Russell Food Equipment                                          30     30
# Sobey’s Food  Warehouse                                         30     30
# Tindahan Food Mart                                              30     30
# United Food & Commercial Workers Local 832                      30     30
# Vinh Long Vietnamese Fast Food                                  30     30
# Will's Sargent Food Mart                                        30     30
# cityplace Food Court                                            30     30
#
#                                             Venue Latitude  Venue Longitude  \
# Neighborhood
# Agriculture & Agri-Food Canada                          30               30
# Canton Food Gallery                                     30               30
# Champs Food Systems Ltd.                                30               30
# Chinese Food Delivery                                   30               30
# Diversity Food services                                 30               30
# Food Court - Portage Place Shopping Centre              30               30
# Food Court Winnipeg Square                              30               30
# Food For Thought                                        60               60
# Food Matters Manitoba                                   30               30
# FoodFare                                               120              120
# Health Food                                             30               30
# Health Sciences Center Food Court                       30               30
# Hi Rise Food Mart                                       30               30
# K&B Lucky Lotto Food Store                              30               30
# Meltwich Food Co.                                       30               30
# Polo Park Food Court                                    30               30
# Pratts Wholesale/Food Service                           30               30
# Royal Food Store                                        30               30
# Russell Food Equipament                                 30               30
# Russell Food Equipment                                  30               30
# Sobey’s Food  Warehouse                                 30               30
# Tindahan Food Mart                                      30               30
# United Food & Commercial Workers Local 832              30               30
# Vinh Long Vietnamese Fast Food                          30               30
# Will's Sargent Food Mart                                30               30
# cityplace Food Court                                    30               30
#
#                                             Venue Category
# Neighborhood
# Agriculture & Agri-Food Canada                          30
# Canton Food Gallery                                     30
# Champs Food Systems Ltd.                                30
# Chinese Food Delivery                                   30
# Diversity Food services                                 30
# Food Court - Portage Place Shopping Centre              30
# Food Court Winnipeg Square                              30
# Food For Thought                                        60
# Food Matters Manitoba                                   30
# FoodFare                                               120
# Health Food                                             30
# Health Sciences Center Food Court                       30
# Hi Rise Food Mart                                       30
# K&B Lucky Lotto Food Store                              30
# Meltwich Food Co.                                       30
# Polo Park Food Court                                    30
# Pratts Wholesale/Food Service                           30
# Royal Food Store                                        30
# Russell Food Equipament                                 30
# Russell Food Equipment                                  30
# Sobey’s Food  Warehouse                                 30
# Tindahan Food Mart                                      30
# United Food & Commercial Workers Local 832              30
# Vinh Long Vietnamese Fast Food                          30
# Will's Sargent Food Mart                                30
# cityplace Food Court                                    30

# %%
winni_onehot = pd.get_dummies(result_venues[['Venue Category']], prefix="", prefix_sep="")
winni_onehot['Neighborhood'] = result_venues['Neighborhood'] 
col_to_fix = [winni_onehot.columns[-1]] + list(winni_onehot.columns[:-1])
winni_onehot = winni_onehot[col_to_fix]
winni_onehot.head()





winni_grouped = winni_onehot.groupby('Neighborhood').mean().reset_index()
winni_grouped




num_top_venues = 5

for hood in winni_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = winni_grouped[winni_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agriculture & Agri-Food Canada----
#           venue  freq
# 0         Hotel  0.10
# 1  Concert Hall  0.07
# 2    Restaurant  0.07
# 3          Café  0.07
# 4         Diner  0.03
#
#
# ----Canton Food Gallery----
#                    venue  freq
# 0       Asian Restaurant  0.13
# 1            Coffee Shop  0.13
# 2  Vietnamese Restaurant  0.10
# 3         Sandwich Place  0.07
# 4                 Bakery  0.07
#
#
# ----Champs Food Systems Ltd.----
#                   venue  freq
# 0                 Hotel  0.13
# 1        Sandwich Place  0.10
# 2  Fast Food Restaurant  0.07
# 3      Asian Restaurant  0.07
# 4                 Diner  0.03
#
#
# ----Chinese Food Delivery----
#                   venue  freq
# 0     Convenience Store  0.10
# 1  Fast Food Restaurant  0.07
# 2      Asian Restaurant  0.07
# 3                Bakery  0.07
# 4        Sandwich Place  0.07
#
#
# ----Diversity Food services----
#                    venue  freq
# 0                   Café  0.10
# 1            Coffee Shop  0.10
# 2  Vietnamese Restaurant  0.07
# 3       Asian Restaurant  0.07
# 4             Restaurant  0.07
#
#
# ----Food Court - Portage Place Shopping Centre----
#           venue  freq
# 0   Coffee Shop  0.10
# 1    Restaurant  0.10
# 2  Concert Hall  0.07
# 3          Café  0.07
# 4   Pizza Place  0.03
#
#
# ----Food Court Winnipeg Square----
#           venue  freq
# 0         Hotel  0.10
# 1    Restaurant  0.10
# 2  Concert Hall  0.07
# 3     Hotel Bar  0.03
# 4         Plaza  0.03
#
#
# ----Food For Thought----
#             venue  freq
# 0      Restaurant  0.07
# 1    Burger Joint  0.05
# 2  Breakfast Spot  0.05
# 3     Coffee Shop  0.05
# 4           Hotel  0.05
#
#
# ----Food Matters Manitoba----
#           venue  freq
# 0          Café  0.13
# 1   Coffee Shop  0.10
# 2           Pub  0.07
# 3  Dessert Shop  0.03
# 4    Steakhouse  0.03
#
#
# ----FoodFare----
#             venue  freq
# 0            Café  0.09
# 1     Coffee Shop  0.08
# 2      Restaurant  0.05
# 3  Ice Cream Shop  0.04
# 4      Steakhouse  0.04
#
#
# ----Health Food----
#                    venue  freq
# 0            Coffee Shop  0.13
# 1                   Café  0.10
# 2  Vietnamese Restaurant  0.07
# 3             Restaurant  0.07
# 4           Concert Hall  0.07
#
#
# ----Health Sciences Center Food Court----
#                    venue  freq
# 0       Asian Restaurant  0.13
# 1           Concert Hall  0.07
# 2            Coffee Shop  0.07
# 3  Vietnamese Restaurant  0.07
# 4                   Café  0.07
#
#
# ----Hi Rise Food Mart----
#           venue  freq
# 0          Café  0.10
# 1   Coffee Shop  0.10
# 2    Restaurant  0.07
# 3  Concert Hall  0.07
# 4     Hotel Bar  0.03
#
#
# ----K&B Lucky Lotto Food Store----
#                    venue  freq
# 0       Asian Restaurant  0.17
# 1  Vietnamese Restaurant  0.13
# 2                 Bakery  0.10
# 3            Coffee Shop  0.07
# 4                  Hotel  0.07
#
#
# ----Meltwich Food Co.----
#           venue  freq
# 0         Hotel  0.10
# 1    Restaurant  0.10
# 2  Concert Hall  0.07
# 3     Hotel Bar  0.03
# 4         Plaza  0.03
#
#
# ----Polo Park Food Court----
#                   venue  freq
# 0        Breakfast Spot  0.07
# 1  Fast Food Restaurant  0.07
# 2           Pizza Place  0.07
# 3                 Hotel  0.07
# 4            Steakhouse  0.07
#
#
# ----Pratts Wholesale/Food Service----
#                   venue  freq
# 0  Fast Food Restaurant  0.23
# 1           Coffee Shop  0.13
# 2           Gas Station  0.10
# 3     Convenience Store  0.10
# 4              Pharmacy  0.07
#
#
# ----Royal Food Store----
#                   venue  freq
# 0     Convenience Store  0.10
# 1  Fast Food Restaurant  0.07
# 2                  Park  0.07
# 3         Grocery Store  0.03
# 4    Falafel Restaurant  0.03
#
#
# ----Russell Food Equipament----
#                    venue  freq
# 0         Breakfast Spot  0.07
# 1          Grocery Store  0.07
# 2  Vietnamese Restaurant  0.07
# 3                  Hotel  0.07
# 4     Mexican Restaurant  0.03
#
#
# ----Russell Food Equipment----
#                    venue  freq
# 0         Breakfast Spot  0.07
# 1          Grocery Store  0.07
# 2  Vietnamese Restaurant  0.07
# 3                  Hotel  0.07
# 4     Mexican Restaurant  0.03
#
#
# ----Sobey’s Food  Warehouse----
#                  venue  freq
# 0                Hotel  0.13
# 1  American Restaurant  0.07
# 2     Asian Restaurant  0.07
# 3               Bakery  0.07
# 4     Sushi Restaurant  0.07
#
#
# ----Tindahan Food Mart----
#                    venue  freq
# 0  Vietnamese Restaurant  0.10
# 1       Asian Restaurant  0.10
# 2                  Hotel  0.07
# 3            Pizza Place  0.07
# 4                 Bakery  0.07
#
#
# ----United Food & Commercial Workers Local 832----
#                   venue  freq
# 0  Fast Food Restaurant  0.07
# 1     Electronics Store  0.07
# 2         Grocery Store  0.07
# 3                 Hotel  0.07
# 4          Burger Joint  0.07
#
#
# ----Vinh Long Vietnamese Fast Food----
#           venue  freq
# 0         Hotel  0.10
# 1          Café  0.07
# 2  Concert Hall  0.07
# 3    Restaurant  0.07
# 4         Plaza  0.03
#
#
# ----Will's Sargent Food Mart----
#                    venue  freq
# 0           Concert Hall  0.10
# 1            Coffee Shop  0.10
# 2  Vietnamese Restaurant  0.07
# 3       Asian Restaurant  0.07
# 4             Restaurant  0.07
#
#
# ----cityplace Food Court----
#           venue  freq
# 0    Restaurant  0.17
# 1   Coffee Shop  0.13
# 2          Café  0.07
# 3     Hotel Bar  0.03
# 4  Burger Joint  0.03

# %%
def venues_top_in(row, num_top_venues):
    row_to_cat = row.iloc[1:]
    row_to_sort = row_to_cat.sort_values(ascending=False)
    
    return row_to_sort.index.values[0:num_top_venues]

# %%
numer_of_favor = 7

indicators = ['st', 'nd', 'rd']
columns = ['Neighborhood']
for ind in np.arange(numer_of_favor):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
        
venues_of_neighbor = pd.DataFrame(columns=columns)
venues_of_neighbor['Neighborhood'] = winni_grouped['Neighborhood']

for ind in np.arange(winni_grouped.shape[0]):
    venues_of_neighbor.iloc[ind, 1:] = venues_top_in(winni_grouped.iloc[ind, :], numer_of_favor)
    
venues_of_neighbor.head()
# Out:
#                      Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0  Agriculture & Agri-Food Canada                 Hotel          Concert Hall
# 1             Canton Food Gallery      Asian Restaurant           Coffee Shop
# 2        Champs Food Systems Ltd.                 Hotel        Sandwich Place
# 3           Chinese Food Delivery     Convenience Store      Asian Restaurant
# 4         Diversity Food services           Coffee Shop                  Café
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0             Restaurant                  Café         Historic Site
# 1  Vietnamese Restaurant        Sandwich Place     Convenience Store
# 2       Asian Restaurant  Fast Food Restaurant         Smoothie Shop
# 3            Pizza Place                Bakery  Fast Food Restaurant
# 4  Vietnamese Restaurant          Concert Hall            Restaurant
#
#   6th Most Common Venue 7th Most Common Venue
# 0          Hockey Arena                 Plaza
# 1                Bakery    Chinese Restaurant
# 2       Warehouse Store                   Inn
# 3        Sandwich Place         Grocery Store
# 4      Asian Restaurant                 Hotel

# %%
# set number of clusters
kclusters = 2
winni_grouped_clustering = winni_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(winni_grouped_clustering)

# check cluster labels generated for each row in the dataframe
#kmeans.labels_[0:10] 
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
