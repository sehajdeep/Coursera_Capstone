# %% [markdown]
# ## Project Description :

# %% [markdown]
# As an international student it is not easy to simply move to another country and settle there. Given so many constraints during the student life, it becomes really important to cut down living cost. For achieveing the same students must have enough information about how to make most of thier time around their College or University. There can be a number of factors which one may want to cosider while chosing the residence. I wish to help the user save his/her time as well as money by avoiding searching for such localities manually but using this project. This project can be used by the user at the time of rental apartment or buy house in a locality based on the distribution of various facilities available around the neighborhood. This project uses K-mean clustering unsupervised machine learning algorithm to cluster the venues based on the place category such as gym, clubs, restaurants, coffee shop, etc. In the end I would want to know what all food places I have around the Red River College in Winnipeg within the radius of 5Kms.

# %% [markdown]
# ## Intended Users:

# %% [markdown]
# Expats or anyone planning to relocate to a different country, Inernational Students of Red River College.

# %% [markdown]
# ## Data:

# %% [markdown]
# This project would use Four-square API as its prime data gathering source. This API provides the ability to perform location search, location sharing and details about a business. Foursquare users can also use photos, tips and reviews in many productive ways to add value to the results. Using this data we will cluster on the basis of factors like most visited places, most pocket friendly places and easy public transport access. I wish to majorly wxplore the city of Winnipeg in Manitoba. Majorly will be using Foresquare API to look for nearby popular places around colleges as well as university. These places will have the potential to be converted to a resedential place or can act as an refference point for someone who is looking for pocket friendly but at the same time famous food places places around their place of recidence which will be within 5 kms.

# %% [markdown]
# ## Methodology

# %% [markdown]
# Out of keen interest to move to a new area for study I am super exieted to know the surrounding of the college I am moving to. I have used the geo data to show the Map of Winnipeg. The Postal Codes have been taken from https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_R :
# ![image.png](attachment:image.png)
# After getting the web page using library BeautifulSoap, the data has been  wrangled into specific format to be used further for Map.
# Folium was used to generate the Map of Winnipeg.
# ![image.png](attachment:image.png)
# Forsquare API is the most useful thing in this project. Using the Venues Search query, I have used "food" keyword to search for all the food joints withing 5kms around the college. Forsqaure API returns required data in JSON format:
# ![image.png](attachment:image.png)
# The JSON data is further processed into a pandas dataframe, so as to make it even more easy to access.
# ![image.png](attachment:image.png)
# After that using explore Forquare API calls I have grouoped the results based on the neighbourhood.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Results:

# %% [markdown]
# Finally I wanted to have a view of the places around the college and there I have it.
# ![image.png](attachment:image.png)
